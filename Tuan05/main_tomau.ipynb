# %% [markdown]
# # Bài tập tô màu

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%writefile TOMAU.INP
# 9
# 1 2
# 1 4
# 1 5
# 2 3
# 3 4
# 3 7
# 4 5
# 4 6
# 5 6
# 5 9
# 6 8
# 6 9
# Out:
# Overwriting TOMAU.INP

# %%
# %run tomau.py - --action test1
# Out:
# ----- DOC FILE -----
# n = 9, edges = [(1, 2), (1, 4), (1, 5), (2, 3), (3, 4), (3, 7), (4, 5), (4, 6), (5, 6), (5, 9), (6, 8), (6, 9)]
# Ket qua:
# 3
# 1 3 6
# 2 4 7 8 9
# 5

# %%
# %run tomau.py - --action main --file TOMAU.INP
# Out:
# 3
# 1 3 6
# 2 4 7 8 9
# 5
